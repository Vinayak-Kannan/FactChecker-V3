# %%
# Load DF
import pandas as pd
df = pd.read_csv('/Users/vinayakkannan/Desktop/Projects/FactChecker/FactChecker/Testing/Test Output/analysis/actual-Table 1.csv')
# Filter df 'Orig Cluster' column where it equals '64'
df = df[df['Orig Cluster'] == 64]
# df = df[df['Orig Cluster'] != -1]
df = df[df['cluster'] != -1]

# %%
df
# Out:
#       Unnamed: 0                                               text  veracity  \
# 3729         752  In 2022, reported emissions from large industr...       3.0
# 3730        1362  Between 1990 and 2023, annual emissions of SO2...       3.0
# 3731        1522  Compared to 2022, the 2023 data show a 15% dec...       3.0
# 3732        2423  Nationwide, emissions for 2023 show the most s...       3.0
# 3733        2428  Net US greenhouse gas emissions were 5,489 mil...       3.0
# 3734        2627  Reported power plant emissions decreased by 0....       3.0
# 3735        3328  There is a 28.7% decrease in emissions since 2...       3.0
# 3736        3640  While complying with programs to reduce SO2, N...       3.0
# 3737         379  According to the Paris-based International Ene...       1.0
# 3738         389  This suggests a second threshold question: whe...       1.0
# 3739         394  In Spain, to take the most extreme example, em...       1.0
# 3740         420  Its emissions rose about 9 percent last year, ...       1.0
# 3741         850  Put another way, over the past decade, U.S. ca...       1.0
# 3742         853  According to the new BP numbers, in 2013 alone...       1.0
# 3743        1093  A total of 1. billion tons of carbon were emit...       1.0
# 3744        1410  But even if China tapered its emissions growth...       1.0
# 3745        1468  Carbon Dioxide Emissions Fall Dramatically, Ag...       1.0
# 3746        1481  China and India are growing so rapidly that th...       1.0
# 3747        1485  China's CO2 emissions increased by 167% betwee...       1.0
# 3748        1532  Consider China: Its carbon emissions increased...       1.0
# 3749        1553  Data from the Energy Information Administratio...       1.0
# 3750        1569  Developing country emissions now exceed those ...       1.0
# 3751        1693  Figure 2 & 3 show the latest territorial distr...       1.0
# 3752        1709  For comparison, the U. S. economy has grown ro...       1.0
# 3753        1948  In 1990, China and India together accounted fo...       1.0
# 3754        1962  In 2005, the baseline year, the United States ...       1.0
# 3755        1963  In 2006, China passed the United States as the...       1.0
# 3756        2067  In contrast, China's carbon-dioxide output soa...       1.0
# 3757        2085  In fact, latest emissions from the Global Carb...       1.0
# 3758        2272  Japan has had little population growth and far...       1.0
# 3759        2284  Just last year experts at the International En...       1.0
# 3760        2388  Moreover, population growth has equaled emissi...       1.0
# 3761        2880  The EIA projects that China's energy-related e...       1.0
# 3762        3003  The United States and Canada have had similar ...       1.0
# 3763        3227  The resulting gross emissions estimate of 0. b...       1.0
# 3764         444  It basically forces developed countries, accou...       1.0
# 3765        1318  At the negotiations in Kyoto, Japan, more than...       1.0
# 3766        1398  But Kim Carstensen, leader of the global clima...       1.0
# 3767        2137  In subsequent months, however, 140 countries d...       1.0
# 3768        2953  The Protocol called for developed countries to...       1.0
# 3769        3208  The reason was that the protocol, by leaving o...       1.0
# 3770        3544  Under Kyoto, 37 nations and the European Union...       1.0
# 3771         146  Presently, the EU ETS is completing its Second...       1.0
# 3772         441  Of greater concern to the system's advocates i...       1.0
# 3773         464  According to the review, the vast majority of ...       1.0
# 3774         469  Fourth, experience in Europe shows emissions t...       1.0
# 3775         714  In 2009, the European Commission called on the...       1.0
# 3776        1307  At least 12 of the 15 EU countries concerned a...       1.0
# 3777        1891  However, in 2011, only 11 percent of credits g...       1.0
# 3778        2019  In March 2012, consulting firm Ecosystem Marke...       1.0
# 3779        2214  It found that more than 20 national and sub-na...       1.0
# 3780        2610  Recent economic data shows the European econom...       1.0
# 3781        3426  This is the sixth time in the last seven years...       1.0
#
#       predict  predicted_veracity  cluster  num_correct_in_cluster  \
# 3729     True                 3.0       78                       8
# 3730    False                 3.0       78                       8
# 3731    False                 3.0       78                       8
# 3732    False                 3.0       78                       8
# 3733    False                 3.0       78                       8
# 3734    False                 3.0       78                       8
# 3735    False                 3.0       78                       8
# 3736    False                 3.0       78                       8
# 3737     True                 1.0       79                      27
# 3738     True                 1.0       79                      27
# 3739     True                 1.0       79                      27
# 3740     True                 1.0       79                      27
# 3741     True                 1.0       79                      27
# 3742     True                 1.0       79                      27
# 3743    False                 1.0       79                      27
# 3744    False                 1.0       79                      27
# 3745    False                 1.0       79                      27
# 3746    False                 1.0       79                      27
# 3747    False                 1.0       79                      27
# 3748    False                 1.0       79                      27
# 3749    False                 1.0       79                      27
# 3750    False                 1.0       79                      27
# 3751    False                 1.0       79                      27
# 3752    False                 1.0       79                      27
# 3753    False                 1.0       79                      27
# 3754    False                 1.0       79                      27
# 3755    False                 1.0       79                      27
# 3756    False                 1.0       79                      27
# 3757    False                 1.0       79                      27
# 3758    False                 1.0       79                      27
# 3759    False                 1.0       79                      27
# 3760    False                 1.0       79                      27
# 3761    False                 1.0       79                      27
# 3762    False                 1.0       79                      27
# 3763    False                 1.0       79                      27
# 3764     True                 1.0       80                       7
# 3765    False                 1.0       80                       7
# 3766    False                 1.0       80                       7
# 3767    False                 1.0       80                       7
# 3768    False                 1.0       80                       7
# 3769    False                 1.0       80                       7
# 3770    False                 1.0       80                       7
# 3771     True                 1.0       81                      11
# 3772     True                 1.0       81                      11
# 3773     True                 1.0       81                      11
# 3774     True                 1.0       81                      11
# 3775     True                 1.0       81                      11
# 3776    False                 1.0       81                      11
# 3777    False                 1.0       81                      11
# 3778    False                 1.0       81                      11
# 3779    False                 1.0       81                      11
# 3780    False                 1.0       81                      11
# 3781    False                 1.0       81                      11
#
#       total_in_cluster  cluster_accuracy  Correct Pred  Cluster count 50  \
# 3729                 8               1.0          True               120
# 3730                 8               1.0          True               120
# 3731                 8               1.0          True               120
# 3732                 8               1.0          True               120
# 3733                 8               1.0          True               120
# 3734                 8               1.0          True               120
# 3735                 8               1.0          True               120
# 3736                 8               1.0          True               120
# 3737                27               1.0          True               120
# 3738                27               1.0          True               120
# 3739                27               1.0          True               120
# 3740                27               1.0          True               120
# 3741                27               1.0          True               120
# 3742                27               1.0          True               120
# 3743                27               1.0          True               120
# 3744                27               1.0          True               120
# 3745                27               1.0          True               120
# 3746                27               1.0          True               120
# 3747                27               1.0          True               120
# 3748                27               1.0          True               120
# 3749                27               1.0          True               120
# 3750                27               1.0          True               120
# 3751                27               1.0          True               120
# 3752                27               1.0          True               120
# 3753                27               1.0          True               120
# 3754                27               1.0          True               120
# 3755                27               1.0          True               120
# 3756                27               1.0          True               120
# 3757                27               1.0          True               120
# 3758                27               1.0          True               120
# 3759                27               1.0          True               120
# 3760                27               1.0          True               120
# 3761                27               1.0          True               120
# 3762                27               1.0          True               120
# 3763                27               1.0          True               120
# 3764                 7               1.0          True               120
# 3765                 7               1.0          True               120
# 3766                 7               1.0          True               120
# 3767                 7               1.0          True               120
# 3768                 7               1.0          True               120
# 3769                 7               1.0          True               120
# 3770                 7               1.0          True               120
# 3771                11               1.0          True               120
# 3772                11               1.0          True               120
# 3773                11               1.0          True               120
# 3774                11               1.0          True               120
# 3775                11               1.0          True               120
# 3776                11               1.0          True               120
# 3777                11               1.0          True               120
# 3778                11               1.0          True               120
# 3779                11               1.0          True               120
# 3780                11               1.0          True               120
# 3781                11               1.0          True               120
#
#       Diff  Orig Cluster
# 3729   112            64
# 3730   112            64
# 3731   112            64
# 3732   112            64
# 3733   112            64
# 3734   112            64
# 3735   112            64
# 3736   112            64
# 3737    93            64
# 3738    93            64
# 3739    93            64
# 3740    93            64
# 3741    93            64
# 3742    93            64
# 3743    93            64
# 3744    93            64
# 3745    93            64
# 3746    93            64
# 3747    93            64
# 3748    93            64
# 3749    93            64
# 3750    93            64
# 3751    93            64
# 3752    93            64
# 3753    93            64
# 3754    93            64
# 3755    93            64
# 3756    93            64
# 3757    93            64
# 3758    93            64
# 3759    93            64
# 3760    93            64
# 3761    93            64
# 3762    93            64
# 3763    93            64
# 3764   113            64
# 3765   113            64
# 3766   113            64
# 3767   113            64
# 3768   113            64
# 3769   113            64
# 3770   113            64
# 3771   109            64
# 3772   109            64
# 3773   109            64
# 3774   109            64
# 3775   109            64
# 3776   109            64
# 3777   109            64
# 3778   109            64
# 3779   109            64
# 3780   109            64
# 3781   109            64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def get_tfidf(cluster):
    # Get all the text in the cluster
    cluster_text = df[df['cluster'] == cluster]['text']
    # Create a tfidf vectorizer that removes stop words and lowercases all words
    vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
    # Fit the vectorizer to the text
    X = vectorizer.fit_transform(cluster_text)
    # Get the feature names
    feature_names = vectorizer.get_feature_names_out()
    # Get the tfidf values
    tfidf = X.toarray()
    # Get the sum of the tfidf values
    tfidf_sum = tfidf.sum(axis=0)
    # Create a dictionary of the feature names and their tfidf values
    tfidf_dict = dict(zip(feature_names, tfidf_sum))
    # Sort the dictionary by tfidf values
    tfidf_dict = dict(sorted(tfidf_dict.items(), key=lambda item: item[1], reverse=True))
    return tfidf_dict

# Get the tfidf for each cluster
tfidf_dict = {}
for cluster in df['cluster'].unique():
    tfidf_dict[cluster] = get_tfidf(cluster)

# %%
# Get the top 10 tfidf words and scores for each cluster. Create a df that contains each claim, the cluster it belongs to, and the top 10 tfidf words and scores
top_tfidf = pd.DataFrame(columns=['Claim', 'Cluster', 'Top 10 Words', 'Top 10 Scores'])
for cluster in df['cluster'].unique():
    tfidf = tfidf_dict[cluster]
    top_words = list(tfidf.keys())[:10]
    top_scores = list(tfidf.values())[:10]
    claims = df[df['cluster'] == cluster]['text']
    for i in range(len(claims)):
        top_tfidf.loc[len(top_tfidf)] = [claims.iloc[i], cluster, top_words, top_scores]

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

api_key = os.getenv("OPEN_AI_KEY")
client = OpenAI(api_key=api_key)

results = []

# Iterate over each cluster
for cluster in df['cluster'].unique():
    # Get the top 10 tfidf words for the cluster
    tfidf = tfidf_dict[cluster]
    top_words = list(tfidf.keys())[:10]

    # Use OpenAI to generate a summary for the cluster
    response = client.chat.completions.create(
         model="gpt-3.5-turbo",
            messages=[
                {
                    "role": "system",
                    "content": f""" Write a one sentence description for a topic cluster of claims that is as 
                    different as possible from other topic clusters. All topic clusters are related to climate 
                    change. Your topic cluster name should be as different from the other topic clusters which are
                    listed below:
                    {", ".join(results)}
                    
                    Up to 10 of the cluster's claims are: 
                    {", ".join(top_words)}
                    
                    Your one sentence description should be at most 10 words and use the TF-IDF terms. Do not write more than 10 words.
                    """
                },
            ]
    ).choices[0].message.content
    
    results.append(response)

    # Print the summary
    print(f"Summary for cluster {cluster}: {response}")
    
    # Add the summary to the df
    df.loc[df['cluster'] == cluster, 'summary'] = response
    
output_df = df
# Out:
# Summary for cluster 78: Air pollutants and their impact on environmental health.
# Summary for cluster 79: Global carbon emissions trends and impacts on the environment.
# Summary for cluster 80: Impact of countries' emissions cuts under the Kyoto Protocol.
# Summary for cluster 81: European Union's Emissions Trading System and national policies.

# %%
df
# Out:
#       Unnamed: 0                                               text  veracity  \
# 3729         752  In 2022, reported emissions from large industr...       3.0
# 3730        1362  Between 1990 and 2023, annual emissions of SO2...       3.0
# 3731        1522  Compared to 2022, the 2023 data show a 15% dec...       3.0
# 3732        2423  Nationwide, emissions for 2023 show the most s...       3.0
# 3733        2428  Net US greenhouse gas emissions were 5,489 mil...       3.0
# 3734        2627  Reported power plant emissions decreased by 0....       3.0
# 3735        3328  There is a 28.7% decrease in emissions since 2...       3.0
# 3736        3640  While complying with programs to reduce SO2, N...       3.0
# 3737         379  According to the Paris-based International Ene...       1.0
# 3738         389  This suggests a second threshold question: whe...       1.0
# 3739         394  In Spain, to take the most extreme example, em...       1.0
# 3740         420  Its emissions rose about 9 percent last year, ...       1.0
# 3741         850  Put another way, over the past decade, U.S. ca...       1.0
# 3742         853  According to the new BP numbers, in 2013 alone...       1.0
# 3743        1093  A total of 1. billion tons of carbon were emit...       1.0
# 3744        1410  But even if China tapered its emissions growth...       1.0
# 3745        1468  Carbon Dioxide Emissions Fall Dramatically, Ag...       1.0
# 3746        1481  China and India are growing so rapidly that th...       1.0
# 3747        1485  China's CO2 emissions increased by 167% betwee...       1.0
# 3748        1532  Consider China: Its carbon emissions increased...       1.0
# 3749        1553  Data from the Energy Information Administratio...       1.0
# 3750        1569  Developing country emissions now exceed those ...       1.0
# 3751        1693  Figure 2 & 3 show the latest territorial distr...       1.0
# 3752        1709  For comparison, the U. S. economy has grown ro...       1.0
# 3753        1948  In 1990, China and India together accounted fo...       1.0
# 3754        1962  In 2005, the baseline year, the United States ...       1.0
# 3755        1963  In 2006, China passed the United States as the...       1.0
# 3756        2067  In contrast, China's carbon-dioxide output soa...       1.0
# 3757        2085  In fact, latest emissions from the Global Carb...       1.0
# 3758        2272  Japan has had little population growth and far...       1.0
# 3759        2284  Just last year experts at the International En...       1.0
# 3760        2388  Moreover, population growth has equaled emissi...       1.0
# 3761        2880  The EIA projects that China's energy-related e...       1.0
# 3762        3003  The United States and Canada have had similar ...       1.0
# 3763        3227  The resulting gross emissions estimate of 0. b...       1.0
# 3764         444  It basically forces developed countries, accou...       1.0
# 3765        1318  At the negotiations in Kyoto, Japan, more than...       1.0
# 3766        1398  But Kim Carstensen, leader of the global clima...       1.0
# 3767        2137  In subsequent months, however, 140 countries d...       1.0
# 3768        2953  The Protocol called for developed countries to...       1.0
# 3769        3208  The reason was that the protocol, by leaving o...       1.0
# 3770        3544  Under Kyoto, 37 nations and the European Union...       1.0
# 3771         146  Presently, the EU ETS is completing its Second...       1.0
# 3772         441  Of greater concern to the system's advocates i...       1.0
# 3773         464  According to the review, the vast majority of ...       1.0
# 3774         469  Fourth, experience in Europe shows emissions t...       1.0
# 3775         714  In 2009, the European Commission called on the...       1.0
# 3776        1307  At least 12 of the 15 EU countries concerned a...       1.0
# 3777        1891  However, in 2011, only 11 percent of credits g...       1.0
# 3778        2019  In March 2012, consulting firm Ecosystem Marke...       1.0
# 3779        2214  It found that more than 20 national and sub-na...       1.0
# 3780        2610  Recent economic data shows the European econom...       1.0
# 3781        3426  This is the sixth time in the last seven years...       1.0
#
#       predict  predicted_veracity  cluster  num_correct_in_cluster  \
# 3729     True                 3.0       78                       8
# 3730    False                 3.0       78                       8
# 3731    False                 3.0       78                       8
# 3732    False                 3.0       78                       8
# 3733    False                 3.0       78                       8
# 3734    False                 3.0       78                       8
# 3735    False                 3.0       78                       8
# 3736    False                 3.0       78                       8
# 3737     True                 1.0       79                      27
# 3738     True                 1.0       79                      27
# 3739     True                 1.0       79                      27
# 3740     True                 1.0       79                      27
# 3741     True                 1.0       79                      27
# 3742     True                 1.0       79                      27
# 3743    False                 1.0       79                      27
# 3744    False                 1.0       79                      27
# 3745    False                 1.0       79                      27
# 3746    False                 1.0       79                      27
# 3747    False                 1.0       79                      27
# 3748    False                 1.0       79                      27
# 3749    False                 1.0       79                      27
# 3750    False                 1.0       79                      27
# 3751    False                 1.0       79                      27
# 3752    False                 1.0       79                      27
# 3753    False                 1.0       79                      27
# 3754    False                 1.0       79                      27
# 3755    False                 1.0       79                      27
# 3756    False                 1.0       79                      27
# 3757    False                 1.0       79                      27
# 3758    False                 1.0       79                      27
# 3759    False                 1.0       79                      27
# 3760    False                 1.0       79                      27
# 3761    False                 1.0       79                      27
# 3762    False                 1.0       79                      27
# 3763    False                 1.0       79                      27
# 3764     True                 1.0       80                       7
# 3765    False                 1.0       80                       7
# 3766    False                 1.0       80                       7
# 3767    False                 1.0       80                       7
# 3768    False                 1.0       80                       7
# 3769    False                 1.0       80                       7
# 3770    False                 1.0       80                       7
# 3771     True                 1.0       81                      11
# 3772     True                 1.0       81                      11
# 3773     True                 1.0       81                      11
# 3774     True                 1.0       81                      11
# 3775     True                 1.0       81                      11
# 3776    False                 1.0       81                      11
# 3777    False                 1.0       81                      11
# 3778    False                 1.0       81                      11
# 3779    False                 1.0       81                      11
# 3780    False                 1.0       81                      11
# 3781    False                 1.0       81                      11
#
#       total_in_cluster  cluster_accuracy  Correct Pred  Cluster count 50  \
# 3729                 8               1.0          True               120
# 3730                 8               1.0          True               120
# 3731                 8               1.0          True               120
# 3732                 8               1.0          True               120
# 3733                 8               1.0          True               120
# 3734                 8               1.0          True               120
# 3735                 8               1.0          True               120
# 3736                 8               1.0          True               120
# 3737                27               1.0          True               120
# 3738                27               1.0          True               120
# 3739                27               1.0          True               120
# 3740                27               1.0          True               120
# 3741                27               1.0          True               120
# 3742                27               1.0          True               120
# 3743                27               1.0          True               120
# 3744                27               1.0          True               120
# 3745                27               1.0          True               120
# 3746                27               1.0          True               120
# 3747                27               1.0          True               120
# 3748                27               1.0          True               120
# 3749                27               1.0          True               120
# 3750                27               1.0          True               120
# 3751                27               1.0          True               120
# 3752                27               1.0          True               120
# 3753                27               1.0          True               120
# 3754                27               1.0          True               120
# 3755                27               1.0          True               120
# 3756                27               1.0          True               120
# 3757                27               1.0          True               120
# 3758                27               1.0          True               120
# 3759                27               1.0          True               120
# 3760                27               1.0          True               120
# 3761                27               1.0          True               120
# 3762                27               1.0          True               120
# 3763                27               1.0          True               120
# 3764                 7               1.0          True               120
# 3765                 7               1.0          True               120
# 3766                 7               1.0          True               120
# 3767                 7               1.0          True               120
# 3768                 7               1.0          True               120
# 3769                 7               1.0          True               120
# 3770                 7               1.0          True               120
# 3771                11               1.0          True               120
# 3772                11               1.0          True               120
# 3773                11               1.0          True               120
# 3774                11               1.0          True               120
# 3775                11               1.0          True               120
# 3776                11               1.0          True               120
# 3777                11               1.0          True               120
# 3778                11               1.0          True               120
# 3779                11               1.0          True               120
# 3780                11               1.0          True               120
# 3781                11               1.0          True               120
#
#       Diff  Orig Cluster                                            summary
# 3729   112            64  Air pollutants and their impact on environment...
# 3730   112            64  Air pollutants and their impact on environment...
# 3731   112            64  Air pollutants and their impact on environment...
# 3732   112            64  Air pollutants and their impact on environment...
# 3733   112            64  Air pollutants and their impact on environment...
# 3734   112            64  Air pollutants and their impact on environment...
# 3735   112            64  Air pollutants and their impact on environment...
# 3736   112            64  Air pollutants and their impact on environment...
# 3737    93            64  Global carbon emissions trends and impacts on ...
# 3738    93            64  Global carbon emissions trends and impacts on ...
# 3739    93            64  Global carbon emissions trends and impacts on ...
# 3740    93            64  Global carbon emissions trends and impacts on ...
# 3741    93            64  Global carbon emissions trends and impacts on ...
# 3742    93            64  Global carbon emissions trends and impacts on ...
# 3743    93            64  Global carbon emissions trends and impacts on ...
# 3744    93            64  Global carbon emissions trends and impacts on ...
# 3745    93            64  Global carbon emissions trends and impacts on ...
# 3746    93            64  Global carbon emissions trends and impacts on ...
# 3747    93            64  Global carbon emissions trends and impacts on ...
# 3748    93            64  Global carbon emissions trends and impacts on ...
# 3749    93            64  Global carbon emissions trends and impacts on ...
# 3750    93            64  Global carbon emissions trends and impacts on ...
# 3751    93            64  Global carbon emissions trends and impacts on ...
# 3752    93            64  Global carbon emissions trends and impacts on ...
# 3753    93            64  Global carbon emissions trends and impacts on ...
# 3754    93            64  Global carbon emissions trends and impacts on ...
# 3755    93            64  Global carbon emissions trends and impacts on ...
# 3756    93            64  Global carbon emissions trends and impacts on ...
# 3757    93            64  Global carbon emissions trends and impacts on ...
# 3758    93            64  Global carbon emissions trends and impacts on ...
# 3759    93            64  Global carbon emissions trends and impacts on ...
# 3760    93            64  Global carbon emissions trends and impacts on ...
# 3761    93            64  Global carbon emissions trends and impacts on ...
# 3762    93            64  Global carbon emissions trends and impacts on ...
# 3763    93            64  Global carbon emissions trends and impacts on ...
# 3764   113            64  Impact of countries' emissions cuts under the ...
# 3765   113            64  Impact of countries' emissions cuts under the ...
# 3766   113            64  Impact of countries' emissions cuts under the ...
# 3767   113            64  Impact of countries' emissions cuts under the ...
# 3768   113            64  Impact of countries' emissions cuts under the ...
# 3769   113            64  Impact of countries' emissions cuts under the ...
# 3770   113            64  Impact of countries' emissions cuts under the ...
# 3771   109            64  European Union's Emissions Trading System and ...
# 3772   109            64  European Union's Emissions Trading System and ...
# 3773   109            64  European Union's Emissions Trading System and ...
# 3774   109            64  European Union's Emissions Trading System and ...
# 3775   109            64  European Union's Emissions Trading System and ...
# 3776   109            64  European Union's Emissions Trading System and ...
# 3777   109            64  European Union's Emissions Trading System and ...
# 3778   109            64  European Union's Emissions Trading System and ...
# 3779   109            64  European Union's Emissions Trading System and ...
# 3780   109            64  European Union's Emissions Trading System and ...
# 3781   109            64  European Union's Emissions Trading System and ...

# %%
 # Join all the claims into one string
claims = ", ".join(df['text'])

 
response = client.chat.completions.create(
     model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": f""" Write a one sentence description for a topic cluster of claims. All topic clusters are related to climate  change. 
                
                The claims are as folows: {claims}
                
                Your one sentence description should be at most 10 words. Do not write more than 10 words. Make the description as specfiic as posssible to the claims.
                """
            },
        ]
).choices[0].message.content

print(response)
# Out:
# Global emissions reductions and changes by year from 1990-2023.

# %%
df = pd.read_csv('/Users/vinayakkannan/Desktop/Projects/FactChecker/FactChecker/Testing/Test Output/analysis/actual-Table 1.csv')
df = df[df['Orig Cluster'] != -1]

def get_tfidf(cluster):
    # Get all the text in the cluster
    cluster_text = df[df['Orig Cluster'] == cluster]['text']
    # Create a tfidf vectorizer that removes stop words and lowercases all words
    vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
    # Fit the vectorizer to the text
    X = vectorizer.fit_transform(cluster_text)
    # Get the feature names
    feature_names = vectorizer.get_feature_names_out()
    # Get the tfidf values
    tfidf = X.toarray()
    # Get the sum of the tfidf values
    tfidf_sum = tfidf.sum(axis=0)
    # Create a dictionary of the feature names and their tfidf values
    tfidf_dict = dict(zip(feature_names, tfidf_sum))
    # Sort the dictionary by tfidf values
    tfidf_dict = dict(sorted(tfidf_dict.items(), key=lambda item: item[1], reverse=True))
    return tfidf_dict

# Get the tfidf for each cluster
tfidf_dict = {}
for cluster in df['Orig Cluster'].unique():
    tfidf_dict[cluster] = get_tfidf(cluster)
    
# Get the top 10 tfidf words and scores for each cluster. Create a df that contains each claim, the cluster it belongs to, and the top 10 tfidf words and scores
top_tfidf = pd.DataFrame(columns=['Claim', 'Cluster', 'Top 10 Words', 'Top 10 Scores'])
for cluster in df['Orig Cluster'].unique():
    tfidf = tfidf_dict[cluster]
    top_words = list(tfidf.keys())[:10]
    top_scores = list(tfidf.values())[:10]
    claims = df[df['Orig Cluster'] == cluster]['text']
    for i in range(len(claims)):
        top_tfidf.loc[len(top_tfidf)] = [claims.iloc[i], cluster, top_words, top_scores]

# %%
# Filter df 'Orig Cluster' column where it equals '64'
df = df[df['Orig Cluster'] == 64]
output = ""

for cluster in df['Orig Cluster'].unique():
    # Get the top 10 tfidf words for the cluster
    tfidf = tfidf_dict[cluster]
    top_words = list(tfidf.keys())[:10]

    # Use OpenAI to generate a summary for the cluster
    response = client.chat.completions.create(
         model="gpt-3.5-turbo",
            messages=[
                {
                    "role": "system",
                    "content": f""" Write a one sentence description for a topic cluster of claims that is as 
                    different as possible from other topic clusters. All topic clusters are related to climate 
                    change. Your topic cluster name should be as different from the other topic clusters which are
                    listed below:
                    {", ".join(results)}
                    
                    Up to 10 of the cluster's claims are: 
                    {", ".join(top_words)}
                    
                    Your one sentence description should be at most 10 words and use the TF-IDF terms. Do not write more than 10 words.
                    """
                },
            ]
    ).choices[0].message.content
    
    results.append(response)

    # Print the summary
    print(f"Summary for cluster {cluster}: {response}")
    
    output = response
    
    # Add the summary to the df
    df.loc[df['cluster'] == cluster, 'summary'] = response
# Out:
# Summary for cluster 64: Global greenhouse gas emissions trends and impact on countries.

# %%
# Set output_df 'Orig Cluster description' column where it equals '64' to output
output_df.loc[output_df['Orig Cluster'] == 64, 'Orig Cluster description'] = output

# %%
output_df
# Out:
#       Unnamed: 0                                               text  veracity  \
# 3729         752  In 2022, reported emissions from large industr...       3.0
# 3730        1362  Between 1990 and 2023, annual emissions of SO2...       3.0
# 3731        1522  Compared to 2022, the 2023 data show a 15% dec...       3.0
# 3732        2423  Nationwide, emissions for 2023 show the most s...       3.0
# 3733        2428  Net US greenhouse gas emissions were 5,489 mil...       3.0
# 3734        2627  Reported power plant emissions decreased by 0....       3.0
# 3735        3328  There is a 28.7% decrease in emissions since 2...       3.0
# 3736        3640  While complying with programs to reduce SO2, N...       3.0
# 3737         379  According to the Paris-based International Ene...       1.0
# 3738         389  This suggests a second threshold question: whe...       1.0
# 3739         394  In Spain, to take the most extreme example, em...       1.0
# 3740         420  Its emissions rose about 9 percent last year, ...       1.0
# 3741         850  Put another way, over the past decade, U.S. ca...       1.0
# 3742         853  According to the new BP numbers, in 2013 alone...       1.0
# 3743        1093  A total of 1. billion tons of carbon were emit...       1.0
# 3744        1410  But even if China tapered its emissions growth...       1.0
# 3745        1468  Carbon Dioxide Emissions Fall Dramatically, Ag...       1.0
# 3746        1481  China and India are growing so rapidly that th...       1.0
# 3747        1485  China's CO2 emissions increased by 167% betwee...       1.0
# 3748        1532  Consider China: Its carbon emissions increased...       1.0
# 3749        1553  Data from the Energy Information Administratio...       1.0
# 3750        1569  Developing country emissions now exceed those ...       1.0
# 3751        1693  Figure 2 & 3 show the latest territorial distr...       1.0
# 3752        1709  For comparison, the U. S. economy has grown ro...       1.0
# 3753        1948  In 1990, China and India together accounted fo...       1.0
# 3754        1962  In 2005, the baseline year, the United States ...       1.0
# 3755        1963  In 2006, China passed the United States as the...       1.0
# 3756        2067  In contrast, China's carbon-dioxide output soa...       1.0
# 3757        2085  In fact, latest emissions from the Global Carb...       1.0
# 3758        2272  Japan has had little population growth and far...       1.0
# 3759        2284  Just last year experts at the International En...       1.0
# 3760        2388  Moreover, population growth has equaled emissi...       1.0
# 3761        2880  The EIA projects that China's energy-related e...       1.0
# 3762        3003  The United States and Canada have had similar ...       1.0
# 3763        3227  The resulting gross emissions estimate of 0. b...       1.0
# 3764         444  It basically forces developed countries, accou...       1.0
# 3765        1318  At the negotiations in Kyoto, Japan, more than...       1.0
# 3766        1398  But Kim Carstensen, leader of the global clima...       1.0
# 3767        2137  In subsequent months, however, 140 countries d...       1.0
# 3768        2953  The Protocol called for developed countries to...       1.0
# 3769        3208  The reason was that the protocol, by leaving o...       1.0
# 3770        3544  Under Kyoto, 37 nations and the European Union...       1.0
# 3771         146  Presently, the EU ETS is completing its Second...       1.0
# 3772         441  Of greater concern to the system's advocates i...       1.0
# 3773         464  According to the review, the vast majority of ...       1.0
# 3774         469  Fourth, experience in Europe shows emissions t...       1.0
# 3775         714  In 2009, the European Commission called on the...       1.0
# 3776        1307  At least 12 of the 15 EU countries concerned a...       1.0
# 3777        1891  However, in 2011, only 11 percent of credits g...       1.0
# 3778        2019  In March 2012, consulting firm Ecosystem Marke...       1.0
# 3779        2214  It found that more than 20 national and sub-na...       1.0
# 3780        2610  Recent economic data shows the European econom...       1.0
# 3781        3426  This is the sixth time in the last seven years...       1.0
#
#       predict  predicted_veracity  cluster  num_correct_in_cluster  \
# 3729     True                 3.0       78                       8
# 3730    False                 3.0       78                       8
# 3731    False                 3.0       78                       8
# 3732    False                 3.0       78                       8
# 3733    False                 3.0       78                       8
# 3734    False                 3.0       78                       8
# 3735    False                 3.0       78                       8
# 3736    False                 3.0       78                       8
# 3737     True                 1.0       79                      27
# 3738     True                 1.0       79                      27
# 3739     True                 1.0       79                      27
# 3740     True                 1.0       79                      27
# 3741     True                 1.0       79                      27
# 3742     True                 1.0       79                      27
# 3743    False                 1.0       79                      27
# 3744    False                 1.0       79                      27
# 3745    False                 1.0       79                      27
# 3746    False                 1.0       79                      27
# 3747    False                 1.0       79                      27
# 3748    False                 1.0       79                      27
# 3749    False                 1.0       79                      27
# 3750    False                 1.0       79                      27
# 3751    False                 1.0       79                      27
# 3752    False                 1.0       79                      27
# 3753    False                 1.0       79                      27
# 3754    False                 1.0       79                      27
# 3755    False                 1.0       79                      27
# 3756    False                 1.0       79                      27
# 3757    False                 1.0       79                      27
# 3758    False                 1.0       79                      27
# 3759    False                 1.0       79                      27
# 3760    False                 1.0       79                      27
# 3761    False                 1.0       79                      27
# 3762    False                 1.0       79                      27
# 3763    False                 1.0       79                      27
# 3764     True                 1.0       80                       7
# 3765    False                 1.0       80                       7
# 3766    False                 1.0       80                       7
# 3767    False                 1.0       80                       7
# 3768    False                 1.0       80                       7
# 3769    False                 1.0       80                       7
# 3770    False                 1.0       80                       7
# 3771     True                 1.0       81                      11
# 3772     True                 1.0       81                      11
# 3773     True                 1.0       81                      11
# 3774     True                 1.0       81                      11
# 3775     True                 1.0       81                      11
# 3776    False                 1.0       81                      11
# 3777    False                 1.0       81                      11
# 3778    False                 1.0       81                      11
# 3779    False                 1.0       81                      11
# 3780    False                 1.0       81                      11
# 3781    False                 1.0       81                      11
#
#       total_in_cluster  cluster_accuracy  Correct Pred  Cluster count 50  \
# 3729                 8               1.0          True               120
# 3730                 8               1.0          True               120
# 3731                 8               1.0          True               120
# 3732                 8               1.0          True               120
# 3733                 8               1.0          True               120
# 3734                 8               1.0          True               120
# 3735                 8               1.0          True               120
# 3736                 8               1.0          True               120
# 3737                27               1.0          True               120
# 3738                27               1.0          True               120
# 3739                27               1.0          True               120
# 3740                27               1.0          True               120
# 3741                27               1.0          True               120
# 3742                27               1.0          True               120
# 3743                27               1.0          True               120
# 3744                27               1.0          True               120
# 3745                27               1.0          True               120
# 3746                27               1.0          True               120
# 3747                27               1.0          True               120
# 3748                27               1.0          True               120
# 3749                27               1.0          True               120
# 3750                27               1.0          True               120
# 3751                27               1.0          True               120
# 3752                27               1.0          True               120
# 3753                27               1.0          True               120
# 3754                27               1.0          True               120
# 3755                27               1.0          True               120
# 3756                27               1.0          True               120
# 3757                27               1.0          True               120
# 3758                27               1.0          True               120
# 3759                27               1.0          True               120
# 3760                27               1.0          True               120
# 3761                27               1.0          True               120
# 3762                27               1.0          True               120
# 3763                27               1.0          True               120
# 3764                 7               1.0          True               120
# 3765                 7               1.0          True               120
# 3766                 7               1.0          True               120
# 3767                 7               1.0          True               120
# 3768                 7               1.0          True               120
# 3769                 7               1.0          True               120
# 3770                 7               1.0          True               120
# 3771                11               1.0          True               120
# 3772                11               1.0          True               120
# 3773                11               1.0          True               120
# 3774                11               1.0          True               120
# 3775                11               1.0          True               120
# 3776                11               1.0          True               120
# 3777                11               1.0          True               120
# 3778                11               1.0          True               120
# 3779                11               1.0          True               120
# 3780                11               1.0          True               120
# 3781                11               1.0          True               120
#
#       Diff  Orig Cluster                                            summary  \
# 3729   112            64  Air pollutants and their impact on environment...
# 3730   112            64  Air pollutants and their impact on environment...
# 3731   112            64  Air pollutants and their impact on environment...
# 3732   112            64  Air pollutants and their impact on environment...
# 3733   112            64  Air pollutants and their impact on environment...
# 3734   112            64  Air pollutants and their impact on environment...
# 3735   112            64  Air pollutants and their impact on environment...
# 3736   112            64  Air pollutants and their impact on environment...
# 3737    93            64  Global carbon emissions trends and impacts on ...
# 3738    93            64  Global carbon emissions trends and impacts on ...
# 3739    93            64  Global carbon emissions trends and impacts on ...
# 3740    93            64  Global carbon emissions trends and impacts on ...
# 3741    93            64  Global carbon emissions trends and impacts on ...
# 3742    93            64  Global carbon emissions trends and impacts on ...
# 3743    93            64  Global carbon emissions trends and impacts on ...
# 3744    93            64  Global carbon emissions trends and impacts on ...
# 3745    93            64  Global carbon emissions trends and impacts on ...
# 3746    93            64  Global carbon emissions trends and impacts on ...
# 3747    93            64  Global carbon emissions trends and impacts on ...
# 3748    93            64  Global carbon emissions trends and impacts on ...
# 3749    93            64  Global carbon emissions trends and impacts on ...
# 3750    93            64  Global carbon emissions trends and impacts on ...
# 3751    93            64  Global carbon emissions trends and impacts on ...
# 3752    93            64  Global carbon emissions trends and impacts on ...
# 3753    93            64  Global carbon emissions trends and impacts on ...
# 3754    93            64  Global carbon emissions trends and impacts on ...
# 3755    93            64  Global carbon emissions trends and impacts on ...
# 3756    93            64  Global carbon emissions trends and impacts on ...
# 3757    93            64  Global carbon emissions trends and impacts on ...
# 3758    93            64  Global carbon emissions trends and impacts on ...
# 3759    93            64  Global carbon emissions trends and impacts on ...
# 3760    93            64  Global carbon emissions trends and impacts on ...
# 3761    93            64  Global carbon emissions trends and impacts on ...
# 3762    93            64  Global carbon emissions trends and impacts on ...
# 3763    93            64  Global carbon emissions trends and impacts on ...
# 3764   113            64  Impact of countries' emissions cuts under the ...
# 3765   113            64  Impact of countries' emissions cuts under the ...
# 3766   113            64  Impact of countries' emissions cuts under the ...
# 3767   113            64  Impact of countries' emissions cuts under the ...
# 3768   113            64  Impact of countries' emissions cuts under the ...
# 3769   113            64  Impact of countries' emissions cuts under the ...
# 3770   113            64  Impact of countries' emissions cuts under the ...
# 3771   109            64  European Union's Emissions Trading System and ...
# 3772   109            64  European Union's Emissions Trading System and ...
# 3773   109            64  European Union's Emissions Trading System and ...
# 3774   109            64  European Union's Emissions Trading System and ...
# 3775   109            64  European Union's Emissions Trading System and ...
# 3776   109            64  European Union's Emissions Trading System and ...
# 3777   109            64  European Union's Emissions Trading System and ...
# 3778   109            64  European Union's Emissions Trading System and ...
# 3779   109            64  European Union's Emissions Trading System and ...
# 3780   109            64  European Union's Emissions Trading System and ...
# 3781   109            64  European Union's Emissions Trading System and ...
#
#                                Orig Cluster description
# 3729  Global greenhouse gas emissions trends and imp...
# 3730  Global greenhouse gas emissions trends and imp...
# 3731  Global greenhouse gas emissions trends and imp...
# 3732  Global greenhouse gas emissions trends and imp...
# 3733  Global greenhouse gas emissions trends and imp...
# 3734  Global greenhouse gas emissions trends and imp...
# 3735  Global greenhouse gas emissions trends and imp...
# 3736  Global greenhouse gas emissions trends and imp...
# 3737  Global greenhouse gas emissions trends and imp...
# 3738  Global greenhouse gas emissions trends and imp...
# 3739  Global greenhouse gas emissions trends and imp...
# 3740  Global greenhouse gas emissions trends and imp...
# 3741  Global greenhouse gas emissions trends and imp...
# 3742  Global greenhouse gas emissions trends and imp...
# 3743  Global greenhouse gas emissions trends and imp...
# 3744  Global greenhouse gas emissions trends and imp...
# 3745  Global greenhouse gas emissions trends and imp...
# 3746  Global greenhouse gas emissions trends and imp...
# 3747  Global greenhouse gas emissions trends and imp...
# 3748  Global greenhouse gas emissions trends and imp...
# 3749  Global greenhouse gas emissions trends and imp...
# 3750  Global greenhouse gas emissions trends and imp...
# 3751  Global greenhouse gas emissions trends and imp...
# 3752  Global greenhouse gas emissions trends and imp...
# 3753  Global greenhouse gas emissions trends and imp...
# 3754  Global greenhouse gas emissions trends and imp...
# 3755  Global greenhouse gas emissions trends and imp...
# 3756  Global greenhouse gas emissions trends and imp...
# 3757  Global greenhouse gas emissions trends and imp...
# 3758  Global greenhouse gas emissions trends and imp...
# 3759  Global greenhouse gas emissions trends and imp...
# 3760  Global greenhouse gas emissions trends and imp...
# 3761  Global greenhouse gas emissions trends and imp...
# 3762  Global greenhouse gas emissions trends and imp...
# 3763  Global greenhouse gas emissions trends and imp...
# 3764  Global greenhouse gas emissions trends and imp...
# 3765  Global greenhouse gas emissions trends and imp...
# 3766  Global greenhouse gas emissions trends and imp...
# 3767  Global greenhouse gas emissions trends and imp...
# 3768  Global greenhouse gas emissions trends and imp...
# 3769  Global greenhouse gas emissions trends and imp...
# 3770  Global greenhouse gas emissions trends and imp...
# 3771  Global greenhouse gas emissions trends and imp...
# 3772  Global greenhouse gas emissions trends and imp...
# 3773  Global greenhouse gas emissions trends and imp...
# 3774  Global greenhouse gas emissions trends and imp...
# 3775  Global greenhouse gas emissions trends and imp...
# 3776  Global greenhouse gas emissions trends and imp...
# 3777  Global greenhouse gas emissions trends and imp...
# 3778  Global greenhouse gas emissions trends and imp...
# 3779  Global greenhouse gas emissions trends and imp...
# 3780  Global greenhouse gas emissions trends and imp...
# 3781  Global greenhouse gas emissions trends and imp...
