# %%
import pandas as pd

cluster_2 = pd.read_csv("/workspaces/FactChecker-V3/Testing/Test Output/Iterations/results_df_0.2.csv")
cluster_4 = pd.read_csv("/workspaces/FactChecker-V3/Testing/Test Output/Iterations/results_df_0.4.csv")
cluster_6 = pd.read_csv("/workspaces/FactChecker-V3/Testing/Test Output/Iterations/results_df_0.6.csv")

# %%
# Filter cluster_2 to columsn that begin with metrics.
cluster_2 = cluster_2.filter(regex='^metrics')
cluster_2
# Out:
#    metrics.accuracy  metrics.accuracy_not_including_fours  \
# 0          0.372781                              0.893617
#
#    metrics.percentage_of_fours  \
# 0                      0.58284
#
#    metrics.percentage_of_no_clusters_in_ground_truth  \
# 0                                                0.0
#
#    metrics.precision_on_three  metrics.recall_on_three  \
# 0                         1.0                 0.424749
#
#    metrics.average_confidence_for_3  \
# 0                                 0
#
#    metrics.precision_on_three_excluding_fours  \
# 0                                         1.0
#
#    metrics.recall_on_three_excluding_fours  metrics.precision_on_one  \
# 0                                 0.944238                       1.0
#
#    metrics.recall_on_one  metrics.precision_on_one_excluding_fours  \
# 0               0.322917                                       1.0
#
#    metrics.recall_on_one_excluding_fours  metrics.precision  metrics.recall  \
# ...

# %%
# Filter cluster_4 to columsn that begin with metrics.
cluster_4 = cluster_4.filter(regex='^metrics')
cluster_4
# Out:
#    metrics.accuracy  metrics.accuracy_not_including_fours  \
# 0          0.338078                                 0.875
#
#    metrics.percentage_of_fours  \
# 0                     0.613625
#
#    metrics.percentage_of_no_clusters_in_ground_truth  \
# 0                                                0.0
#
#    metrics.precision_on_three  metrics.recall_on_three  \
# 0                         1.0                 0.403399
#
#    metrics.average_confidence_for_3  \
# 0                                 0
#
#    metrics.precision_on_three_excluding_fours  \
# 0                                         1.0
#
#    metrics.recall_on_three_excluding_fours  metrics.precision_on_one  \
# 0                                  0.96162                       1.0
#
#    metrics.recall_on_one  metrics.precision_on_one_excluding_fours  \
# 0               0.291553                                       1.0
#
#    metrics.recall_on_one_excluding_fours  metrics.precision  metrics.recall  \
# ...

# %%
# Filter cluster_4 to columsn that begin with metrics.
cluster_6 = cluster_6.filter(regex='^metrics')
cluster_6
# Out:
#    metrics.accuracy  metrics.accuracy_not_including_fours  \
# 0          0.007722                              0.421053
#
#    metrics.percentage_of_fours  \
# 0                      0.98166
#
#    metrics.percentage_of_no_clusters_in_ground_truth  \
# 0                                                0.0
#
#    metrics.precision_on_three  metrics.recall_on_three  \
# 0                         0.0                      0.0
#
#    metrics.average_confidence_for_3  \
# 0                                 0
#
#    metrics.precision_on_three_excluding_fours  \
# 0                                         0.0
#
#    metrics.recall_on_three_excluding_fours  metrics.precision_on_one  \
# 0                                      0.0                       1.0
#
#    metrics.recall_on_one  metrics.precision_on_one_excluding_fours  \
# 0                0.01581                                       1.0
#
#    metrics.recall_on_one_excluding_fours  metrics.precision  metrics.recall  \
# ...
